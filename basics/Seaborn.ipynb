# %%
import pandas as pd
import seaborn as sns

# %%
file = 'data/Iris_Data.csv'
data = pd.read_csv(file)
sns.jointplot(x='sepal_width', y='sepal_length', data=data, size=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
